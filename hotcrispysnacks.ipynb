# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 8,4

# %%
x = range(1,10)
y = [1,2,3,4,.5,4,3,2,1]

# %%
plt.bar(x,y)
plt.xlabel('your x-axis label ')
# Out:
# Text(0.5, 0, 'your x-axis label ')

# %%
z = [1,2,3,4,.5]
city_veh_type = ['bicycle' , 'motorbike', 'car','van', 'stroller']
plt.pie(z, labels=veh_type)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
stored_database=pd.read_csv('C:/Users/maity/OneDrive/Desktop/Pworld/colorfulcharts/mtcars.csv')

# %%
mpg=stored_database.mpg

# %%
stored_database.columns=['car_names' , 'mpg', 'cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']

# %%
mpg=stored_database.mpg
fig = plt.figure()
ax = fig.add_axes([.2,.2,2,2])
mpg.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(stored_database.car_names, rotation=60, fontsize='large')
ax.set_title('DIFFERENT VARITIES OF CARS AROUND THE CITY')
ax.set_xlabel('car_names')
ax.set_ylabel('miles/gal')
# Out:
# Text(0, 0.5, 'miles/gal')

# %%
plt.pie(z)
plt.legend(veh_type,loc='best')

# %%
fig = plt.figure()
ax = fig.add_axes([.2,.2,2,2])
mpg.plot()
ax.set_xticks(range(32))
ax.set_xticklabels(stored_database.car_names, rotation=60, fontsize='large')
ax.set_title('Miles per gallons of cars in DATASETS')
ax.set_xlabel('car_names')
ax.set_ylabel('miles/gal')
ax.legend(loc='best')
ax.set_ylim([0,45])
ax.annotate('Toyota Corolla', xy = (19,33.9),xytext=(21,35),arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(21, 35, 'Toyota Corolla')
